# %% [markdown]
# <a href="https://colab.research.google.com/github/ameerfayiz/ChatTTS_colab/blob/main/chattts_webui_mix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Markdown

message = """
### 🌟 If you think ChatTTS and ChatTTS_colab projects are helpful to you, please visit the following links to give them a star! 🌟

- [ChatTTS project](https://github.com/2noise/ChatTTS)

- [ChatTTS_colab project](https://github.com/6drf21e/ChatTTS_colab)

Thank you for your support!

### Running method ###

- Click on the menu bar -- Code execution program -- Run all

- After execution, find something like in the log below

Running on public URL: https://**************.gradio.live <- This is the public network address that can be accessed

When the package is installed, it prompts to restart, please click **"No"**

"""
display(Markdown(message))
# Out:
# ### 🌟 If you think ChatTTS and ChatTTS_colab projects are helpful to you, please visit the following links to give them a star! 🌟
#
# - [ChatTTS project](https://github.com/2noise/ChatTTS)
#
# - [ChatTTS_colab project](https://github.com/6drf21e/ChatTTS_colab)
#
# Thank you for your support!
#
# ### Running method ###
#
# - Click on the menu bar -- Code execution program -- Run all
#
# - After execution, find something like in the log below
#
# Running on public URL: https://**************.gradio.live <- This is the public network address that can be accessed
#
# When the package is installed, it prompts to restart, please click **"No"**

# %%
# !git clone -q https://github.com/ameerfayiz/ChatTTS_colab
# %cd ChatTTS_colab
# !git clone -q https://github.com/2noise/ChatTTS
# %cd ChatTTS
# !git checkout -q f4c8329
# %cd ..
# !mv ChatTTS abc
# !mv abc/ChatTTS ./ChatTTS
# !pip install -q omegaconf vocos vector_quantize_pytorch gradio cn2an pypinyin openai jieba
# 启动 Gradio 有公网地址
# !python webui_mix.py --share
# Out:
# /content/ChatTTS_colab
# /content/ChatTTS_colab/ChatTTS
# /content/ChatTTS_colab
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 47.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 16.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 57.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.5/325.5 kB 28.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 72.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 12.5 MB/s eta 0:00:00
# ...
